# %% [markdown]
# # Exploring conventional netCDF diag files

# %%
from GSI_diags import Conventional
from filter_df import filter_df
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import matplotlib.colors as mcolors
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %% [markdown]
# ### Read the file

# %%
diagFilePath = '../example_data/diag_conv_t_ges.2024031812.nc4'
diag = Conventional(diagFilePath)

# %% [markdown]
# ### Print some metadata

# %%
diag_dict = diag.__dict__
diag_dict['obs_ids']
# Out:
# array([133, 131, 180, 181, 187, 188, 120, 195, 130, 194, 193, 183, 192,
#        126, 134], dtype=int32)

# %%
diag.metadata
# Out:
# {'Obs Type': 'conv',
#  'Variable': 't',
#  'Date': datetime.datetime(2024, 3, 18, 12, 0),
#  'File Type': 'ges',
#  'Diag File Type': 'conventional'}

# %% [markdown]
# ### Get data

# %%
data = diag.get_data()

# %%
data
# Out:
#       station_id observation_class  observation_type  observation_subtype  \
# 0       NLOYR3BA                 t               133                    0
# 1       PPSAPQJA                 t               133                    0
# 2       EH5SSIJA                 t               133                    0
# 3         AU0332                 t               131                    0
# 4         AU0332                 t               131                    0
# ...          ...               ...               ...                  ...
# 95286      C3583                 t               188                    0
# 95287      D9120                 t               188                    0
# 95288      AS353                 t               188                    0
# 95289      AS353                 t               188                    0
# 95290      E3920                 t               188                    0
#
#         latitude   longitude  station_elevation     pressure   height  \
# 0       3.083000  202.462006            10668.0   238.399994  10668.0
# 1       7.012000  199.987000            11582.0   206.500000  11582.0
# 2      11.715000  198.373001            11582.0   206.500000  11582.0
# 3       9.415200  197.984207            11200.0   219.300003  11200.0
# 4       8.791900  197.248703            11500.0   209.199997  11500.0
# ...          ...         ...                ...          ...      ...
# 95286  43.470501  356.220490               14.0  1017.000000     14.0
# 95287  43.477329  352.668671               50.0  1013.799988     50.0
# 95288  43.537998  354.376160               17.0  1015.299988     17.0
# 95289  43.537998  354.376160               17.0  1015.200012     17.0
# 95290  46.472172  353.171997              445.0   966.000000    445.0
#
#           time  ...  errinv_final  observation  omf_adjusted  omf_unadjusted  \
# 0     -0.47944  ...  1.130850e+00   232.149994      0.764870        0.764870
# 1     -0.08167  ...  1.081445e+00   225.149994      1.653118        1.653118
# 2     -0.56222  ...  1.081445e+00   226.149994      2.252426        2.252426
# 3     -0.91417  ...  1.091483e+00   227.149994      0.339865        0.339865
# 4     -0.78972  ...  1.068424e+00   224.649994     -0.110163       -0.110163
# ...        ...  ...           ...          ...           ...             ...
# 95286 -0.03333  ...  1.523826e+00   288.750000      1.462522        1.362427
# 95287 -0.25000  ...  2.938736e-39   205.350006    -81.465019      -81.437431
# 95288 -0.25000  ...  1.240138e+00   288.750000      1.823937        1.760007
# 95289 -0.08333  ...  1.228414e+00   288.750000      1.823937        1.767725
# 95290 -0.25000  ...  1.000000e-10   285.350006     -0.628849        1.882655
#
#            data_pof  data_vertical_velocity  dominant_sfc_type  model_terrain  \
# 0     -9.990000e+09           -9.990000e+09                0.0            0.0
# 1     -9.990000e+09           -9.990000e+09                0.0            0.0
# 2     -9.990000e+09           -9.990000e+09                0.0            0.0
# 3     -9.990000e+09           -9.990000e+09                0.0            0.0
# 4     -9.990000e+09           -9.990000e+09                0.0            0.0
# ...             ...                     ...                ...            ...
# 95286 -9.990000e+09           -9.990000e+09                0.0            0.0
# 95287 -9.990000e+09           -9.990000e+09                0.0            0.0
# 95288 -9.990000e+09           -9.990000e+09                0.0            0.0
# 95289 -9.990000e+09           -9.990000e+09                0.0            0.0
# 95290 -9.990000e+09           -9.990000e+09                0.0            0.0
#
#        hofx_unadjusted  hofx_adjusted
# 0           231.385117     231.385117
# 1           223.496872     223.496872
# 2           223.897568     223.897568
# 3           226.810135     226.810135
# 4           224.760162     224.760162
# ...                ...            ...
# 95286       287.387573     287.287476
# 95287       286.787445     286.815033
# 95288       286.989990     286.926056
# 95289       286.982269     286.926056
# 95290       283.467346     285.978851
#
# [95291 rows x 27 columns]
