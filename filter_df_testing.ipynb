# %%
from pyGSI.diags import Conventional
import numpy as np
import pandas as pd
from filter_df import filter_df

# %%
pd.set_option('display.max_columns', None) # so I can see all columns on the df

# %% [markdown]
# # Filter dataframe returned by PyGSI

# %% [markdown]
# One big question with this is to use PyGSI or just to borrow some of the code and have with package not rely on PyGSI at all?

# %% [markdown]
# ## Read diag files

# %%
diag_ges_fp = './diag_conv_t_ges.2024031812.nc4'
diag_anl_fp = './diag_conv_t_anl.2024031812.nc4'

diag_ges = Conventional(diag_ges_fp)
diag_anl = Conventional(diag_anl_fp)

# %% [markdown]
# ## Query data and preprocess dataframes

# %% [markdown]
# This includes removing the indexing that PyGSI defaults to and changes non-assimilated obs to flag 0 instead of -1 for convenience

# %%
data_ges = diag_ges.get_data().reset_index()
data_anl = diag_anl.get_data().reset_index()

data_ges.loc[data_ges['Analysis_Use_Flag'] == -1, 'Analysis_Use_Flag'] = 0
data_anl.loc[data_anl['Analysis_Use_Flag'] == -1, 'Analysis_Use_Flag'] = 0

# %% [markdown]
# ## Testing PyGSI filter_obs function

# %% [markdown]
# ### Set filter arguments

# %%
hem = "GLOBAL"
obs_types = [120]
use = 1
lat_range = (80, 90)
lon_range = (0, 300)
elv_range = (0,20)

# %%
new_df = filter_df(data_anl, use=use, elv_range=elv_range, obs_types=obs_types)

# %%
new_df
# Out:
#       Station_ID Observation_Class  Observation_Type  Observation_Subtype  \
# 258        91285                 t               120                    0
# 259        91285                 t               120                    0
# 260        91285                 t               120                    0
# 261        91285                 t               120                    0
# 262        91285                 t               120                    0
# ...          ...               ...               ...                  ...
# 94973      78970                 t               120                    0
# 94974      78970                 t               120                    0
# 94975      78970                 t               120                    0
# 94976      78970                 t               120                    0
# 94977      78970                 t               120                    0
#
#           Pressure        Height  Analysis_Use_Flag   latitude   longitude  \
# 258    1016.000000  1.200000e+01                1.0  19.719999  204.949997
# 259    1009.000000  1.000000e+11                1.0  19.720039  204.949951
# 260    1000.000000  1.480000e+02                1.0  19.719879  204.949707
# 261     925.000000  8.160000e+02                1.0  19.715191  204.946533
# 262     906.000000  1.000000e+11                1.0  19.713869  204.946289
# ...            ...           ...                ...        ...         ...
# 94973   954.997559  1.000000e+11                1.0  10.578935  298.641754
# 94974   735.108459  1.000000e+11                1.0  10.590825  298.590302
# 94975   554.504333  1.000000e+11                1.0  10.587209  298.553253
# 94976   456.260468  1.000000e+11                1.0  10.588181  298.544067
# 94977   128.414871  1.000000e+11                1.0  10.486543  298.750336
#
#        station_elevation      time  prep_qc_mark  setup_qc_mark  \
# 258                 12.0 -0.900000           2.0            1.0
# 259                 12.0 -0.896680           2.0            1.0
# 260                 12.0 -0.892440           2.0            1.0
# 261                 12.0 -0.855330           2.0            1.0
# 262                 12.0 -0.845580           2.0            1.0
# ...                  ...       ...           ...            ...
# 94973               12.0 -0.771283           2.0            1.0
# 94974               12.0 -0.646837           2.0            1.0
# 94975               12.0 -0.518425           2.0            1.0
# 94976               12.0 -0.432795           2.0            1.0
# 94977               12.0  0.048056           2.0            1.0
#
#        prep_use_flag  nonlinear_qc_rel_wgt  errinv_input  errinv_adjust  \
# 258              0.0                   4.0      0.725258       0.594881
# 259              0.0                   4.0      0.720031       0.453006
# 260              0.0                   4.0      0.713419       0.607291
# 261              0.0                   4.0      0.687380       0.687380
# 262              0.0                   4.0      0.687200       0.548553
# ...              ...                   ...           ...            ...
# 94973            0.0                   4.0      0.687521       0.581402
# 94974            0.0                   4.0      0.848905       0.848905
# 94975            0.0                   4.0      1.045510       1.045510
# 94976            0.0                   4.0      1.065798       1.065798
# 94977            0.0                   4.0      0.722121       0.722121
#
#        errinv_final  observation  omf_adjusted  omf_unadjusted      data_pof  \
# 258        0.594881   292.350006     -0.398379       -0.398379 -9.990000e+09
# 259        0.453006   293.750000      0.669440        0.669440 -9.990000e+09
# 260        0.607291   293.149994      0.079321        0.079321 -9.990000e+09
# 261        0.687380   287.549988     -0.357033       -0.357033 -9.990000e+09
# 262        0.548553   286.549988     -0.397200       -0.397200 -9.990000e+09
# ...             ...          ...           ...             ...           ...
# 94973      0.581402   296.224426      1.264579        1.264579 -9.990000e+09
# 94974      0.848905   285.821472      0.099764        0.099764 -9.990000e+09
# 94975      1.045510   274.115875      0.603464        0.603464 -9.990000e+09
# 94976      1.065798   265.254883      0.381959        0.381959 -9.990000e+09
# 94977      0.722121   202.017609      0.321480        0.321480 -9.990000e+09
#
#        data_vertical_velocity  dominant_sfc_type  model_terrain  \
# 258             -9.990000e+09                4.0      22.206355
# 259             -9.990000e+09                4.0      22.191899
# 260             -9.990000e+09                4.0      22.258473
# 261             -9.990000e+09                4.0      34.779372
# 262             -9.990000e+09                4.0      37.925920
# ...                       ...                ...            ...
# 94973           -9.990000e+09                1.0      17.465707
# 94974           -9.990000e+09                1.0       9.743429
# 94975           -9.990000e+09                1.0       7.842573
# 94976           -9.990000e+09                4.0       6.908435
# 94977           -9.990000e+09                1.0      76.328853
#
#        hofx_unadjusted  hofx_adjusted
# 258         292.748383     292.748383
# 259         293.080566     293.080566
# 260         293.070679     293.070679
# 261         287.907013     287.907013
# 262         286.947174     286.947174
# ...                ...            ...
# 94973       294.959839     294.959839
# 94974       285.721710     285.721710
# 94975       273.512421     273.512421
# 94976       264.872925     264.872925
# 94977       201.696121     201.696121
#
# [1865 rows x 27 columns]
